# %% [markdown]
# # Task 4: Implement UNET for Image Denoising
#
# This notebook implements a simple UNET model to denoise an image using PyTorch.

# %%
import torch
import torch.nn as nn

# %% [markdown]
# ## Define a Basic UNET Architecture

# %%
class UNet(nn.Module):
    def __init__(self):
        super(UNet, self).__init__()
        self.encoder = nn.Conv2d(1, 16, 3, padding=1)
        self.decoder = nn.ConvTranspose2d(16, 1, 3, padding=1)

    def forward(self, x):
        x = torch.relu(self.encoder(x))
        x = torch.sigmoid(self.decoder(x))
        return x

# %% [markdown]
# ## Create and Test the UNET Model

# %%
# Create a UNET model
model = UNet()
image = torch.randn(1, 1, 128, 128)  # Example input
output = model(image)
print("Denoised image shape:", output.shape)
